# %%
import pandas as pd
import numpy as np
df = pd.read_csv("bitcoin_price.csv", parse_dates=['Date'])

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                object
# Market Cap            object
# dtype: object

# %%
df.describe()
# Out:
#                Open          High           Low         Close
# count   1760.000000   1760.000000   1760.000000   1760.000000
# mean    1479.574239   1536.991108   1418.251273   1485.747000
# std     2950.457188   3092.950362   2780.859459   2959.265478
# min       68.500000     74.560000     65.530000     68.430000
# 25%      274.730000    279.857500    268.640000    274.875000
# 50%      480.715000    495.195000    472.510000    482.810000
# 75%      870.085000    900.222500    831.682500    871.370000
# max    19475.800000  20089.000000  18974.100000  19497.400000

# %%
df_bp = df[['Date','Open', 'Close']]
df_bp = df_bp.set_index('Date')
df_bp['Year'] = df_bp.index.year
df_bp = df_bp.groupby(['Year'])
df1_bp = df_bp.get_group(2013)
df1_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df2_bp = df_bp.get_group(2014)
df2_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df3_bp = df_bp.get_group(2015)
df3_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df4_bp = df_bp.get_group(2016)
df4_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df5_bp = df_bp.get_group(2017)
df5_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df6_bp = df_bp.get_group(2018)
df6_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df1 = df[['Date','Open']]
df1_ts = df1.set_index('Date')
df1_ts.sort_index(inplace=True)
df1_ts.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2 = df[['Date','Close']]
df2_ts = df2.set_index('Date')
df2_ts.sort_index(inplace=True)
df2_ts.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
