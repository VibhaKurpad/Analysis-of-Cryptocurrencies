# %%
import pandas as pd
import numpy as np
df = pd.read_csv("ethereum_price.csv", parse_dates=['Date'])

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                object
# Market Cap            object
# dtype: object

# %%
df.describe()
# Out:
#               Open         High          Low        Close
# count   929.000000   929.000000   929.000000   929.000000
# mean    146.897500   154.363413   139.114778   147.784327
# std     263.218553   277.620377   247.137437   264.130846
# min       0.431589     0.482988     0.420897     0.434829
# 25%       7.890000     8.270000     7.570000     7.910000
# 50%      12.050000    12.430000    11.720000    12.020000
# 75%     245.260000   257.000000   223.980000   245.990000
# max    1397.480000  1432.880000  1290.600000  1396.420000

# %%
df_bp = df[['Date','Open', 'Close']]
df_bp = df_bp.set_index('Date')
df_bp['Year'] = df_bp.index.year
df_bp = df_bp.groupby(['Year'])
df1_bp = df_bp.get_group(2015)
df1_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df2_bp = df_bp.get_group(2016)
df2_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df3_bp = df_bp.get_group(2017)
df3_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df4_bp = df_bp.get_group(2018)
df4_bp.boxplot(by='Year')
# Out:
# array([<AxesSubplot:title={'center':'Close'}, xlabel='[Year]'>,
#        <AxesSubplot:title={'center':'Open'}, xlabel='[Year]'>],
#       dtype=object)

# %%
df1 = df[['Date','Open']]
df1_ts = df1.set_index('Date')
df1_ts.sort_index(inplace=True)
df1_ts.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2 = df[['Date','Close']]
df2_ts = df2.set_index('Date')
df2_ts.sort_index(inplace=True)
df2_ts.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
